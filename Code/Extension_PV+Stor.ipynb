# %% [markdown]
# # Addition of PV and local storage units at busses 3 and 4

# %%
using JuMP, HiGHS

# ------------------------------
# Data and Parameters
# ------------------------------

# Time periods
T = 1:8

# Scenarios
scenarios = 1:9

# Scenario probabilities (equal probabilities)
prob = Dict(s => 1/9 for s in scenarios)

# Wind availability at Bus 5 (stochastic, per scenario and time period)
W = Dict(
    (1,1) => 32.63, (1,2) => 31.40, (1,3) => 28.52, (1,4) => 31.40, (1,5) => 33.26, (1,6) => 33.43, (1,7) => 34.59, (1,8) => 34.06,
    (2,1) => 32.63, (2,2) => 31.40, (2,3) => 28.52, (2,4) => 31.40, (2,5) => 33.26, (2,6) => 33.43, (2,7) => 34.59, (2,8) => 34.06,
    (3,1) => 32.63, (3,2) => 31.40, (3,3) => 28.52, (3,4) => 31.40, (3,5) => 33.26, (3,6) => 33.43, (3,7) => 34.59, (3,8) => 34.06,
    
    (4,1) => 15.79, (4,2) => 13.04, (4,3) => 10.11, (4,4) => 10.33, (4,5) => 11.47, (4,6) => 12.69, (4,7) => 15.69, (4,8) => 16.73,
    (5,1) => 15.79, (5,2) => 13.04, (5,3) => 10.11, (5,4) => 10.33, (5,5) => 11.47, (5,6) => 12.69, (5,7) => 15.69, (5,8) => 16.73,
    (6,1) => 15.79, (6,2) => 13.04, (6,3) => 10.11, (6,4) => 10.33, (6,5) => 11.47, (6,6) => 12.69, (6,7) => 15.69, (6,8) => 16.73,

    (7,1) => 53.79, (7,2) => 54.13, (7,3) => 59.43, (7,4) => 66.39, (7,5) => 67.63, (7,6) => 64.22, (7,7) => 60.45, (7,8) => 55.51,
    (8,1) => 53.79, (8,2) => 54.13, (8,3) => 59.43, (8,4) => 66.39, (8,5) => 67.63, (8,6) => 64.22, (8,7) => 60.45, (8,8) => 55.51,
    (9,1) => 53.79, (9,2) => 54.13, (9,3) => 59.43, (9,4) => 66.39, (9,5) => 67.63, (9,6) => 64.22, (9,7) => 60.45, (9,8) => 55.51
)

# Dynamic load at Bus 1 (stochastic, per scenario and time period)
D = Dict(
    (1,1) => 5.0, (1,2) => 8.2, (1,3) => 20.5, (1,4) => 35.0, (1,5) => 42.8, (1,6) => 38.4, (1,7) => 25.1, (1,8) => 12.0,
    (2,1) => 10.0, (2,2) => 15.4, (2,3) => 30.7, (2,4) => 50.2, (2,5) => 61.3, (2,6) => 55.0, (2,7) => 35.7, (2,8) => 18.5,
    (3,1) => 15.0, (3,2) => 22.5, (3,3) => 42.1, (3,4) => 68.9, (3,5) => 82.5, (3,6) => 74.2, (3,7) => 48.6, (3,8) => 25.9,

    (4,1) => 5.0, (4,2) => 8.2, (4,3) => 20.5, (4,4) => 35.0, (4,5) => 42.8, (4,6) => 38.4, (4,7) => 25.1, (4,8) => 12.0,
    (5,1) => 10.0, (5,2) => 15.4, (5,3) => 30.7, (5,4) => 50.2, (5,5) => 61.3, (5,6) => 55.0, (5,7) => 35.7, (5,8) => 18.5,
    (6,1) => 15.0, (6,2) => 22.5, (6,3) => 42.1, (6,4) => 68.9, (6,5) => 82.5, (6,6) => 74.2, (6,7) => 48.6, (6,8) => 25.9,

    (7,1) => 5.0, (7,2) => 8.2, (7,3) => 20.5, (7,4) => 35.0, (7,5) => 42.8, (7,6) => 38.4, (7,7) => 25.1, (7,8) => 12.0,
    (8,1) => 10.0, (8,2) => 15.4, (8,3) => 30.7, (8,4) => 50.2, (8,5) => 61.3, (8,6) => 55.0, (8,7) => 35.7, (8,8) => 18.5,
    (9,1) => 15.0, (9,2) => 22.5, (9,3) => 42.1, (9,4) => 68.9, (9,5) => 82.5, (9,6) => 74.2, (9,7) => 48.6, (9,8) => 25.9
)

# Stochastic PV availability at Bus 3 (maximum available, per scenario and time period)
PV = Dict(
    (1,1) => 0.0,  (1,2) => 0.51,  (1,3) => 14.71, (1,4) => 43.31, (1,5) => 34.40, (1,6) => 6.39,  (1,7) => 0.09,  (1,8) => 0.0,
    (2,1) => 0.0,  (2,2) => 0.51,  (2,3) => 14.71, (2,4) => 43.31, (2,5) => 34.40, (2,6) => 6.39,  (2,7) => 0.09,  (2,8) => 0.0,
    (3,1) => 0.0,  (3,2) => 0.51,  (3,3) => 14.71, (3,4) => 43.31, (3,5) => 34.40, (3,6) => 6.39,  (3,7) => 0.09,  (3,8) => 0.0,

    (4,1) => 0.0,  (4,2) => 2.39,  (4,3) => 35.49, (4,4) => 68.73, (4,5) => 59.69, (4,6) => 19.08, (4,7) => 0.49,  (4,8) => 0.0,
    (5,1) => 0.0,  (5,2) => 2.39,  (5,3) => 35.49, (5,4) => 68.73, (5,5) => 59.69, (5,6) => 19.08, (5,7) => 0.49,  (5,8) => 0.0,
    (6,1) => 0.0,  (6,2) => 2.39,  (6,3) => 35.49, (6,4) => 68.73, (6,5) => 59.69, (6,6) => 19.08, (6,7) => 0.49,  (6,8) => 0.0,

    (7,1) => 0.0,  (7,2) => 0.04,  (7,3) => 2.66,  (7,4) => 12.62, (7,5) => 11.59, (7,6) => 1.30,  (7,7) => 0.01,  (7,8) => 0.0,
    (8,1) => 0.0,  (8,2) => 0.04,  (8,3) => 2.66,  (8,4) => 12.62, (8,5) => 11.59, (8,6) => 1.30,  (8,7) => 0.01,  (8,8) => 0.0,
    (9,1) => 0.0,  (9,2) => 0.04,  (9,3) => 2.66,  (9,4) => 12.62, (9,5) => 11.59, (9,6) => 1.30,  (9,7) => 0.01,  (9,8) => 0.0
)


# Conventional generation parameters at Bus 1
Gmax = 250.0   # Maximum generation capacity at Bus 1
c_g = 10.0     # Generation cost per unit
c_curt = 5.0 # Penalty cost per unit of wind curtailment 

# Penalty cost for load shedding 
c_ls = 100.0

# Ramping limits for conventional generation (per time period)
ramp_up = 50.0
ramp_down = 50.0

# Network parameters for DC load flow
X = 1.0  # Reactance 
Fmax = 250.0  # Flow limits on all lines


# ------------------------------
# Storage Parameters (for buses 3 and 4)
# ------------------------------

# Maximum storage energy (MWh)
E_max3 = 50.0
E_max4 = 50.0

# Maximum charging/discharging power (MW)
P_ch_max3 = 20.0
P_dis_max3 = 20.0
P_ch_max4 = 20.0
P_dis_max4 = 20.0

# Charging and discharging efficiencies
eta_ch = 0.95
eta_dis = 0.95

# Initial state-of-charge (MWh)
E_init3 = 0.0
E_init4 = 0.0
# Out:
# 0.0

# %%
# ------------------------------
# Model Definition
# ------------------------------
model = Model(HiGHS.Optimizer)

# Conventional generation at Bus 1 (indexed by scenario and time)
@variable(model, g_conv[s in scenarios, t in T] >= 0, upper_bound = Gmax)

# Wind generation at Bus 5 (indexed by scenario and time)
@variable(model, g_wind[s in scenarios, t in T] >= 0)
@variable(model, c_w[s in scenarios, t in T] >= 0)

# PV generation at Bus 3 and Bus 4 (indexed by scenario and time)
@variable(model, g_PV3[s in scenarios, t in T] >= 0)
@variable(model, c_pv3[s in scenarios, t in T] >= 0)
@variable(model, g_PV4[s in scenarios, t in T] >= 0)
@variable(model, c_pv4[s in scenarios, t in T] >= 0)

# Storage variables for Bus 3:
@variable(model, E3[s in scenarios, t in T] >= 0)       # State-of-charge
@variable(model, p_ch3[s in scenarios, t in T] >= 0)    # Charging power
@variable(model, p_dis3[s in scenarios, t in T] >= 0)   # Discharging power

# Storage variables for Bus 4:
@variable(model, E4[s in scenarios, t in T] >= 0)       # State-of-charge
@variable(model, p_ch4[s in scenarios, t in T] >= 0)    # Charging power
@variable(model, p_dis4[s in scenarios, t in T] >= 0)   # Discharging power

# Network flows on each line (indexed by scenario and time)
@variable(model, f51[s in scenarios, t in T])
@variable(model, f12[s in scenarios, t in T])
@variable(model, f23[s in scenarios, t in T])
@variable(model, f24[s in scenarios, t in T])

# Voltage angles at buses 1 through 5 (indexed by scenario and time)
@variable(model, theta[bus in 1:5, s in scenarios, t in T])

# Fix reference angle at Bus 1 for all scenarios and time periods
for s in scenarios, t in T
    @constraint(model, theta[1,s,t] == 0)
end

@variable(model, LS3[s in scenarios, t in T] >= 0)
@variable(model, LS4[s in scenarios, t in T] >= 0)

# ------------------------------
# Objective Function
# ------------------------------

# The objective minimizes the cost of conventional generation and penalizes unused renewables.
@objective(model, Min, 
    sum(prob[s] * (c_g * g_conv[s,t] + c_curt * (c_w[s,t] + c_pv3[s,t] + c_pv4[s,t]) 
    + c_ls * (LS3[s,t] + LS4[s,t])) for s in scenarios, t in T))


# ------------------------------
# Constraints
# ------------------------------

# Wind generation constraint: wind used must not exceed available wind.
for s in scenarios, t in T
    @constraint(model, g_wind[s,t] + c_w[s,t] == W[(s,t)])

end

# PV generation constraints at Bus 3 and Bus 4:
for s in scenarios, t in T
    @constraint(model, g_PV3[s,t] + c_pv3[s,t] == PV[(s,t)])
    @constraint(model, g_PV4[s,t] + c_pv4[s,t] == PV[(s,t)])
end

# Storage charging/discharging limits and energy capacity constraints at Bus 3:
for s in scenarios, t in T
    @constraint(model, p_ch3[s,t] <= P_ch_max3)
    @constraint(model, p_dis3[s,t] <= P_dis_max3)
    @constraint(model, E3[s,t] <= E_max3)
end

# Storage charging/discharging limits and energy capacity constraints at Bus 4:
for s in scenarios, t in T
    @constraint(model, p_ch4[s,t] <= P_ch_max4)
    @constraint(model, p_dis4[s,t] <= P_dis_max4)
    @constraint(model, E4[s,t] <= E_max4)
end

# Storage dynamic constraints for Bus 3:
for s in scenarios
    # Initial period dynamics for Bus 3:
    @constraint(model, E3[s,1] == E_init3 + eta_ch * p_ch3[s,1] - (1/eta_dis) * p_dis3[s,1])
    # Subsequent periods:
    for t in T[2:end]
        @constraint(model, E3[s,t] == E3[s,t-1] + eta_ch * p_ch3[s,t] - (1/eta_dis) * p_dis3[s,t])
    end
end

# Storage dynamic constraints for Bus 4:
for s in scenarios
    # Initial period dynamics for Bus 4:
    @constraint(model, E4[s,1] == E_init4 + eta_ch * p_ch4[s,1] - (1/eta_dis) * p_dis4[s,1])
    # Subsequent periods:
    for t in T[2:end]
        @constraint(model, E4[s,t] == E4[s,t-1] + eta_ch * p_ch4[s,t] - (1/eta_dis) * p_dis4[s,t])
    end
end

# DC power flow equations and flow limits for each line, scenario, and time period:
for s in scenarios, t in T
    @constraint(model, f51[s,t] == (theta[5,s,t] - theta[1,s,t]) / X)
    @constraint(model, f12[s,t] == (theta[1,s,t] - theta[2,s,t]) / X)
    @constraint(model, f23[s,t] == (theta[2,s,t] - theta[3,s,t]) / X)
    @constraint(model, f24[s,t] == (theta[2,s,t] - theta[4,s,t]) / X)
    
    @constraint(model, f51[s,t] <= Fmax)
    @constraint(model, -f51[s,t] <= Fmax)
    @constraint(model, f12[s,t] <= Fmax)
    @constraint(model, -f12[s,t] <= Fmax)
    @constraint(model, f23[s,t] <= Fmax)
    @constraint(model, -f23[s,t] <= Fmax)
    @constraint(model, f24[s,t] <= Fmax)
    @constraint(model, -f24[s,t] <= Fmax)
end

# Power balance constraints at each bus for each scenario and time period:
for s in scenarios, t in T
    # Bus 5 (wind bus): Wind generation flows to Bus 1.
    @constraint(model, g_wind[s,t] - f51[s,t] == 0)
    
    # Bus 1: Conventional generation plus inflow from Bus 5 meets its own demand and supplies Bus 2.
    @constraint(model, g_conv[s,t] - D[(s,t)] + f51[s,t] - f12[s,t] == 0)
    
    # Bus 2: Receives power from Bus 1, meets its dynamic load, and sends power to Buses 3 and 4.
    @constraint(model, f12[s,t] - D[(s,t)] - f23[s,t] - f24[s,t] == 0)
    
    # Bus 3: Local PV generation at Bus 3 now contributes to meeting the fixed demand.
    @constraint(model, f23[s,t] + LS3[s,t] + g_PV3[s,t] - D[(s,t)] - p_ch3[s,t] + p_dis3[s,t] == 0)
    
    # Bus 4: Local PV generation at Bus 4 now contributes to meeting the fixed demand.
    @constraint(model, f24[s,t] + LS4[s,t] + g_PV4[s,t] - D[(s,t)] - p_ch4[s,t] + p_dis4[s,t] == 0)
end

# Ramping constraints for conventional generation at Bus 1 (for each scenario, between consecutive time periods):
for s in scenarios, t in T[2:end]
    @constraint(model, g_conv[s,t] - g_conv[s,t-1] <= ramp_up)
    @constraint(model, g_conv[s,t-1] - g_conv[s,t] <= ramp_down)
end

# %%
# ------------------------------
# Solve the Model
# ------------------------------

optimize!(model)
# Out:
# Running HiGHS 1.8.1 (git hash: 4a7f24ac6): Copyright (c) 2024 HiGHS under MIT licence terms
# Coefficient ranges:
#   Matrix [9e-01, 1e+00]
#   Cost   [6e-01, 1e+01]
#   Bound  [2e+02, 2e+02]
#   RHS    [1e-02, 2e+02]
# Presolving model
# 558 rows, 1044 cols, 1926 nonzeros  0s
# 460 rows, 1009 cols, 1730 nonzeros  0s
# Presolve : Reductions: rows 460(-1754); columns 1009(-719); elements 1730(-2752)
# Solving the presolved LP
# Using EKK dual simplex solver - serial
#   Iteration        Objective     Infeasibilities num(sum)
#           0     0.0000000000e+00 Ph1: 0(0) 0s
#         526     6.5105124694e+03 Pr: 0(0) 0s
# Solving the original LP from the solution after postsolve
# Model status        : Optimal
# Simplex   iterations: 526
# Objective value     :  6.5105124694e+03
# Relative P-D gap    :  1.1175706441e-15
# HiGHS run time      :          0.01

# %%
# ------------------------------
# Output the Results
# ------------------------------

println("Overall Optimal Objective Value: ", objective_value(model))

# Print results per scenario and time period
for s in scenarios, t in T
    println("Scenario $s, Time Period $t:")
    println("  Conventional Generation (Bus 1): ", value(g_conv[s,t]))
    println("  Wind Generation Used (Bus 5): ", value(g_wind[s,t]))
    println("  Wind Curtailment (Bus 5): ", W[(s,t)] - value(g_wind[s,t]))
    println("  PV Generation at Bus 3: ", value(g_PV3[s,t]))
    println("  Storage at Bus 3: SoC = ", value(E3[s,t]),
            ", Charge = ", value(p_ch3[s,t]),
            ", Discharge = ", value(p_dis3[s,t]))
    println("  PV Generation at Bus 4: ", value(g_PV4[s,t]))
    println("  Storage at Bus 4: SoC = ", value(E4[s,t]),
            ", Charge = ", value(p_ch4[s,t]),
            ", Discharge = ", value(p_dis4[s,t]))
end
# Out:
# Overall Optimal Objective Value: 6510.512469412315
# Scenario 1, Time Period 1:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 32.63
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 11.598500000000003, Charge = 12.208947368421057, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.3999999999999989, Charge = 0.42105263157894623, Discharge = 0.0
# Scenario 1, Time Period 2:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 31.4
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.51
#   Storage at Bus 3: SoC = 11.598500000000003, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.51
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.379999999999999
# Scenario 1, Time Period 3:
#   Conventional Generation (Bus 1): 14.73142499999999
#   Wind Generation Used (Bus 5): 28.52
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 14.71
#   Storage at Bus 3: SoC = 1.7789473684210464, Charge = 0.0, Discharge = 9.32857500000001
#   PV Generation at Bus 4: 14.71
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 0.0
# Scenario 1, Time Period 4:
#   Conventional Generation (Bus 1): 21.979999999999997
#   Wind Generation Used (Bus 5): 31.4
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 43.31
#   Storage at Bus 3: SoC = 1.7789473684210464, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 43.31
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 1, Time Period 5:
#   Conventional Generation (Bus 1): 69.13999999999999
#   Wind Generation Used (Bus 5): 33.26
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 34.4
#   Storage at Bus 3: SoC = 1.7789473684210464, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 34.4
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 1, Time Period 6:
#   Conventional Generation (Bus 1): 107.38999999999999
#   Wind Generation Used (Bus 5): 33.43
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 6.39
#   Storage at Bus 3: SoC = 1.7789473684210464, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 6.39
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 1, Time Period 7:
#   Conventional Generation (Bus 1): 63.94
#   Wind Generation Used (Bus 5): 34.59
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.09
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 1.6899999999999942
#   PV Generation at Bus 4: 0.09
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 1, Time Period 8:
#   Conventional Generation (Bus 1): 13.939999999999998
#   Wind Generation Used (Bus 5): 34.06
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = -0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 2, Time Period 1:
#   Conventional Generation (Bus 1): 7.369999999999997
#   Wind Generation Used (Bus 5): 32.63
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 2, Time Period 2:
#   Conventional Generation (Bus 1): 29.18
#   Wind Generation Used (Bus 5): 31.4
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.51
#   Storage at Bus 3: SoC = 0.0, Charge = -0.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.51
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 2, Time Period 3:
#   Conventional Generation (Bus 1): 79.18
#   Wind Generation Used (Bus 5): 28.52
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 14.71
#   Storage at Bus 3: SoC = 0.0, Charge = -0.0, Discharge = 0.0
#   PV Generation at Bus 4: 14.71
#   Storage at Bus 4: SoC = 13.604000000000003, Charge = 14.320000000000004, Discharge = 0.0
# Scenario 2, Time Period 4:
#   Conventional Generation (Bus 1): 109.57562326869805
#   Wind Generation Used (Bus 5): 31.4
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 43.31
#   Storage at Bus 3: SoC = 6.455842105263149, Charge = 6.795623268698052, Discharge = 0.0
#   PV Generation at Bus 4: 43.31
#   Storage at Bus 4: SoC = 32.604, Charge = 20.0, Discharge = 0.0
# Scenario 2, Time Period 5:
#   Conventional Generation (Bus 1): 159.57562326869805
#   Wind Generation Used (Bus 5): 33.26
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 34.4
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 15.365041551246547, Discharge = 0.0
#   PV Generation at Bus 4: 34.4
#   Storage at Bus 4: SoC = 33.62105263157894, Charge = 1.0705817174515175, Discharge = 0.0
# Scenario 2, Time Period 6:
#   Conventional Generation (Bus 1): 139.94
#   Wind Generation Used (Bus 5): 33.43
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 6.39
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 20.0
#   PV Generation at Bus 4: 6.39
#   Storage at Bus 4: SoC = 19.042105263157897, Charge = 0.0, Discharge = 13.849999999999994
# Scenario 2, Time Period 7:
#   Conventional Generation (Bus 1): 89.94
#   Wind Generation Used (Bus 5): 34.59
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.09
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.09
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 18.090000000000003
# Scenario 2, Time Period 8:
#   Conventional Generation (Bus 1): 39.94
#   Wind Generation Used (Bus 5): 34.06
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = -0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 3, Time Period 1:
#   Conventional Generation (Bus 1): 27.369999999999997
#   Wind Generation Used (Bus 5): 32.63
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 3, Time Period 2:
#   Conventional Generation (Bus 1): 74.56157788267025
#   Wind Generation Used (Bus 5): 31.4
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.51
#   Storage at Bus 3: SoC = 7.656132590410654, Charge = 8.059086937274373, Discharge = 0.0
#   PV Generation at Bus 4: 0.51
#   Storage at Bus 4: SoC = 8.47636639812614, Charge = 8.922490945395937, Discharge = 0.0
# Scenario 3, Time Period 3:
#   Conventional Generation (Bus 1): 124.56157788267024
#   Wind Generation Used (Bus 5): 28.52
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 14.71
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 14.101577882670226, Discharge = 0.0
#   PV Generation at Bus 4: 14.71
#   Storage at Bus 4: SoC = 8.47636639812614, Charge = 0.0, Discharge = 0.0
# Scenario 3, Time Period 4:
#   Conventional Generation (Bus 1): 174.56157788267024
#   Wind Generation Used (Bus 5): 31.4
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 43.31
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 43.31
#   Storage at Bus 4: SoC = 24.608865386662906, Charge = 16.981577882670223, Discharge = 0.0
# Scenario 3, Time Period 5:
#   Conventional Generation (Bus 1): 224.56157788267024
#   Wind Generation Used (Bus 5): 33.26
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 34.4
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 34.4
#   Storage at Bus 4: SoC = 21.052631578947366, Charge = 0.0, Discharge = 3.378422117329763
# Scenario 3, Time Period 6:
#   Conventional Generation (Bus 1): 210.59
#   Wind Generation Used (Bus 5): 33.43
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 6.39
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 20.0
#   PV Generation at Bus 4: 6.39
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 20.0
# Scenario 3, Time Period 7:
#   Conventional Generation (Bus 1): 160.59
#   Wind Generation Used (Bus 5): 34.59
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.09
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.09
#   Storage at Bus 4: SoC = 0.9120000000000142, Charge = 0.9600000000000151, Discharge = 0.0
# Scenario 3, Time Period 8:
#   Conventional Generation (Bus 1): 110.59
#   Wind Generation Used (Bus 5): 33.00999999999999
#   Wind Curtailment (Bus 5): 1.0500000000000114
#   PV Generation at Bus 3: 0.0
#   Storage at Bus 3: SoC = 19.0, Charge = 20.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.0
#   Storage at Bus 4: SoC = 19.912000000000013, Charge = 20.0, Discharge = 0.0
# Scenario 4, Time Period 1:
#   Conventional Generation (Bus 1): 4.210000000000001
#   Wind Generation Used (Bus 5): 15.79
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 4, Time Period 2:
#   Conventional Generation (Bus 1): 14.979999999999997
#   Wind Generation Used (Bus 5): 13.04
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 2.39
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 2.39
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 4, Time Period 3:
#   Conventional Generation (Bus 1): 0.9099999999999966
#   Wind Generation Used (Bus 5): 10.11
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 35.49
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 35.49
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 4, Time Period 4:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 10.33
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 68.73
#   Storage at Bus 3: SoC = 7.400500000000005, Charge = 7.790000000000006, Discharge = 0.0
#   PV Generation at Bus 4: 68.73
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 4, Time Period 5:
#   Conventional Generation (Bus 1): 44.46538764783179
#   Wind Generation Used (Bus 5): 11.47
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 59.69
#   Storage at Bus 3: SoC = 11.310118265440229, Charge = 4.115387647831814, Discharge = 0.0
#   PV Generation at Bus 4: 59.69
#   Storage at Bus 4: SoC = -0.0, Charge = -0.0, Discharge = 0.0
# Scenario 4, Time Period 6:
#   Conventional Generation (Bus 1): 94.46538764783179
#   Wind Generation Used (Bus 5): 12.69
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 19.08
#   Storage at Bus 3: SoC = 2.5894736842105384, Charge = 0.0, Discharge = 8.284612352168207
#   PV Generation at Bus 4: 19.08
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 4, Time Period 7:
#   Conventional Generation (Bus 1): 81.27
#   Wind Generation Used (Bus 5): 15.69
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.49
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 2.4600000000000115
#   PV Generation at Bus 4: 0.49
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 0.0
# Scenario 4, Time Period 8:
#   Conventional Generation (Bus 1): 31.27
#   Wind Generation Used (Bus 5): 16.73
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = -0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 5, Time Period 1:
#   Conventional Generation (Bus 1): 24.21
#   Wind Generation Used (Bus 5): 15.79
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 5, Time Period 2:
#   Conventional Generation (Bus 1): 43.78
#   Wind Generation Used (Bus 5): 13.04
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 2.39
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 2.39
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 5, Time Period 3:
#   Conventional Generation (Bus 1): 41.709999999999994
#   Wind Generation Used (Bus 5): 10.11
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 35.49
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 35.49
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 5, Time Period 4:
#   Conventional Generation (Bus 1): 75.71047091412743
#   Wind Generation Used (Bus 5): 10.33
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 68.73
#   Storage at Bus 3: SoC = 2.5654473684210646, Charge = 2.7004709141274366, Discharge = 0.0
#   PV Generation at Bus 4: 68.73
#   Storage at Bus 4: SoC = 19.0, Charge = 20.0, Discharge = 0.0
# Scenario 5, Time Period 5:
#   Conventional Generation (Bus 1): 125.71047091412743
#   Wind Generation Used (Bus 5): 11.47
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 59.69
#   Storage at Bus 3: SoC = 13.35789473684214, Charge = 11.360470914127447, Discharge = 0.0
#   PV Generation at Bus 4: 59.69
#   Storage at Bus 4: SoC = 19.0, Charge = 0.0, Discharge = 0.0
# Scenario 5, Time Period 6:
#   Conventional Generation (Bus 1): 157.26999999999998
#   Wind Generation Used (Bus 5): 12.69
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 19.08
#   Storage at Bus 3: SoC = 0.8526315789473783, Charge = 0.0, Discharge = 11.880000000000024
#   PV Generation at Bus 4: 19.08
#   Storage at Bus 4: SoC = 19.0, Charge = 0.0, Discharge = 0.0
# Scenario 5, Time Period 7:
#   Conventional Generation (Bus 1): 107.27
#   Wind Generation Used (Bus 5): 15.69
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.49
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 0.8100000000000094
#   PV Generation at Bus 4: 0.49
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 18.05
# Scenario 5, Time Period 8:
#   Conventional Generation (Bus 1): 57.269999999999996
#   Wind Generation Used (Bus 5): 16.73
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = -0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 6, Time Period 1:
#   Conventional Generation (Bus 1): 44.21
#   Wind Generation Used (Bus 5): 15.79
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 6, Time Period 2:
#   Conventional Generation (Bus 1): 72.18
#   Wind Generation Used (Bus 5): 13.04
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 2.39
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 2.39
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 6, Time Period 3:
#   Conventional Generation (Bus 1): 110.90809787626965
#   Wind Generation Used (Bus 5): 10.11
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 35.49
#   Storage at Bus 3: SoC = 3.4181929824561657, Charge = 3.598097876269648, Discharge = 0.0
#   PV Generation at Bus 4: 35.49
#   Storage at Bus 4: SoC = 19.0, Charge = 20.0, Discharge = 0.0
# Scenario 6, Time Period 4:
#   Conventional Generation (Bus 1): 160.90809787626964
#   Wind Generation Used (Bus 5): 10.33
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 68.73
#   Storage at Bus 3: SoC = 22.418192982456166, Charge = 20.0, Discharge = 0.0
#   PV Generation at Bus 4: 68.73
#   Storage at Bus 4: SoC = 31.443192982456154, Charge = 13.098097876269636, Discharge = 0.0
# Scenario 6, Time Period 5:
#   Conventional Generation (Bus 1): 210.90809787626964
#   Wind Generation Used (Bus 5): 11.47
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 59.69
#   Storage at Bus 3: SoC = 22.926315789473698, Charge = 0.5348661126500338, Discharge = 0.0
#   PV Generation at Bus 4: 59.69
#   Storage at Bus 4: SoC = 42.10526315789473, Charge = 11.223231763619557, Discharge = 0.0
# Scenario 6, Time Period 6:
#   Conventional Generation (Bus 1): 205.95
#   Wind Generation Used (Bus 5): 12.69
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 19.08
#   Storage at Bus 3: SoC = 1.8736842105263318, Charge = 0.0, Discharge = 20.0
#   PV Generation at Bus 4: 19.08
#   Storage at Bus 4: SoC = 21.052631578947366, Charge = 0.0, Discharge = 20.0
# Scenario 6, Time Period 7:
#   Conventional Generation (Bus 1): 155.95
#   Wind Generation Used (Bus 5): 15.69
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.49
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 1.7800000000000153
#   PV Generation at Bus 4: 0.49
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 20.0
# Scenario 6, Time Period 8:
#   Conventional Generation (Bus 1): 105.94999999999999
#   Wind Generation Used (Bus 5): 16.73
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 18.125999999999998, Charge = 19.08, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = -0.0, Charge = 0.0, Discharge = 0.0
# Scenario 7, Time Period 1:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 53.79
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 13.100499999999998, Charge = 13.79, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 19.0, Charge = 20.0, Discharge = 0.0
# Scenario 7, Time Period 2:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 54.13
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.04
#   Storage at Bus 3: SoC = 14.440000000000001, Charge = 1.4100000000000037, Discharge = 0.0
#   PV Generation at Bus 4: 0.04
#   Storage at Bus 4: SoC = 38.0, Charge = 20.0, Discharge = 0.0
# Scenario 7, Time Period 3:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 59.43
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 2.66
#   Storage at Bus 3: SoC = 2.1263157894736686, Charge = 0.0, Discharge = 11.698000000000016
#   PV Generation at Bus 4: 2.66
#   Storage at Bus 4: SoC = 32.15578947368423, Charge = 0.0, Discharge = 5.551999999999984
# Scenario 7, Time Period 4:
#   Conventional Generation (Bus 1): 28.370000000000005
#   Wind Generation Used (Bus 5): 66.39
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 12.62
#   Storage at Bus 3: SoC = 2.1263157894736686, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 12.62
#   Storage at Bus 4: SoC = 11.103157894736864, Charge = 0.0, Discharge = 20.0
# Scenario 7, Time Period 5:
#   Conventional Generation (Bus 1): 78.37
#   Wind Generation Used (Bus 5): 67.63
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 11.59
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 2.0199999999999854
#   PV Generation at Bus 4: 11.59
#   Storage at Bus 4: SoC = 11.103157894736864, Charge = 0.0, Discharge = 0.0
# Scenario 7, Time Period 6:
#   Conventional Generation (Bus 1): 76.23199999999997
#   Wind Generation Used (Bus 5): 64.22
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 1.3
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 1.3
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 10.548000000000021
# Scenario 7, Time Period 7:
#   Conventional Generation (Bus 1): 39.92999999999999
#   Wind Generation Used (Bus 5): 60.45
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.01
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = -0.0
#   PV Generation at Bus 4: 0.01
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 7, Time Period 8:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 55.51
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 7.134499999999997, Charge = 7.509999999999998, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.0, Charge = -0.0, Discharge = 0.0
# Scenario 8, Time Period 1:
#   Conventional Generation (Bus 1): 0.0
#   Wind Generation Used (Bus 5): 53.79
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 2.953776315789504, Charge = 3.109238227146846, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 10.146723684210496, Charge = 10.680761772853154, Discharge = 0.0
# Scenario 8, Time Period 2:
#   Conventional Generation (Bus 1): 17.245713296398886
#   Wind Generation Used (Bus 5): 54.13
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.04
#   Storage at Bus 3: SoC = 12.316703947368422, Charge = 9.855713296398886, Discharge = 0.0
#   PV Generation at Bus 4: 0.04
#   Storage at Bus 4: SoC = 10.146723684210496, Charge = 0.0, Discharge = 0.0
# Scenario 8, Time Period 3:
#   Conventional Generation (Bus 1): 67.24571329639889
#   Wind Generation Used (Bus 5): 59.43
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 2.66
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 9.195713296398889, Discharge = 0.0
#   PV Generation at Bus 4: 2.66
#   Storage at Bus 4: SoC = 10.146723684210496, Charge = 0.0, Discharge = 0.0
# Scenario 8, Time Period 4:
#   Conventional Generation (Bus 1): 117.2457132963989
#   Wind Generation Used (Bus 5): 66.39
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 12.62
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 12.62
#   Storage at Bus 4: SoC = 17.818651315789474, Charge = 8.075713296398888, Discharge = 0.0
# Scenario 8, Time Period 5:
#   Conventional Generation (Bus 1): 167.2457132963989
#   Wind Generation Used (Bus 5): 67.63
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 11.59
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 11.59
#   Storage at Bus 4: SoC = 30.031578947368427, Charge = 12.855713296398898, Discharge = 0.0
# Scenario 8, Time Period 6:
#   Conventional Generation (Bus 1): 118.49000000000001
#   Wind Generation Used (Bus 5): 64.22
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 1.3
#   Storage at Bus 3: SoC = -0.0, Charge = 0.0, Discharge = 20.0
#   PV Generation at Bus 4: 1.3
#   Storage at Bus 4: SoC = 14.568421052631589, Charge = 0.0, Discharge = 14.689999999999998
# Scenario 8, Time Period 7:
#   Conventional Generation (Bus 1): 68.49000000000001
#   Wind Generation Used (Bus 5): 60.45
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.01
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.01
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 13.84000000000001
# Scenario 8, Time Period 8:
#   Conventional Generation (Bus 1): 18.490000000000002
#   Wind Generation Used (Bus 5): 55.51
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = -0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = -0.0
# Scenario 9, Time Period 1:
#   Conventional Generation (Bus 1): 23.204275092936797
#   Wind Generation Used (Bus 5): 53.79
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: -0.0
#   Storage at Bus 3: SoC = 0.30314909019758574, Charge = 0.3191043054711429, Discharge = 0.0
#   PV Generation at Bus 4: -0.0
#   Storage at Bus 4: SoC = 15.841412248092396, Charge = 16.67517078746568, Discharge = 0.0
# Scenario 9, Time Period 2:
#   Conventional Generation (Bus 1): 73.2042750929368
#   Wind Generation Used (Bus 5): 54.13
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.04
#   Storage at Bus 3: SoC = 19.303149090197586, Charge = 20.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.04
#   Storage at Bus 4: SoC = 32.384973586382344, Charge = 17.414275092936784, Discharge = 0.0
# Scenario 9, Time Period 3:
#   Conventional Generation (Bus 1): 123.2042750929368
#   Wind Generation Used (Bus 5): 59.43
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 2.66
#   Storage at Bus 3: SoC = 37.87971042848758, Charge = 19.554275092936805, Discharge = 0.0
#   PV Generation at Bus 4: 2.66
#   Storage at Bus 4: SoC = 32.384973586382344, Charge = 0.0, Discharge = 0.0
# Scenario 9, Time Period 4:
#   Conventional Generation (Bus 1): 173.2042750929368
#   Wind Generation Used (Bus 5): 66.39
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 12.62
#   Storage at Bus 3: SoC = 37.87971042848758, Charge = 0.0, Discharge = 0.0
#   PV Generation at Bus 4: 12.62
#   Storage at Bus 4: SoC = 21.052631578947366, Charge = 0.0, Discharge = 10.765724907063229
# Scenario 9, Time Period 5:
#   Conventional Generation (Bus 1): 223.2042750929368
#   Wind Generation Used (Bus 5): 67.63
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 11.59
#   Storage at Bus 3: SoC = 21.052631578947366, Charge = 0.0, Discharge = 15.9857249070632
#   PV Generation at Bus 4: 11.59
#   Storage at Bus 4: SoC = 21.052631578947366, Charge = 0.0, Discharge = 0.0
# Scenario 9, Time Period 6:
#   Conventional Generation (Bus 1): 189.98000000000002
#   Wind Generation Used (Bus 5): 64.22
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 1.3
#   Storage at Bus 3: SoC = 0.0, Charge = 0.0, Discharge = 20.0
#   PV Generation at Bus 4: 1.3
#   Storage at Bus 4: SoC = 0.0, Charge = 0.0, Discharge = 20.0
# Scenario 9, Time Period 7:
#   Conventional Generation (Bus 1): 139.98000000000002
#   Wind Generation Used (Bus 5): 60.45
#   Wind Curtailment (Bus 5): 0.0
#   PV Generation at Bus 3: 0.01
#   Storage at Bus 3: SoC = 0.0, Charge = -0.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.01
#   Storage at Bus 4: SoC = 5.74750000000001, Charge = 6.050000000000011, Discharge = 0.0
# Scenario 9, Time Period 8:
#   Conventional Generation (Bus 1): 89.98000000000002
#   Wind Generation Used (Bus 5): 53.619999999999976
#   Wind Curtailment (Bus 5): 1.8900000000000219
#   PV Generation at Bus 3: 0.0
#   Storage at Bus 3: SoC = 19.0, Charge = 20.0, Discharge = 0.0
#   PV Generation at Bus 4: 0.0
#   Storage at Bus 4: SoC = 24.74750000000001, Charge = 20.0, Discharge = 0.0

# %%
println("Expected Conventional Generation: ", sum(prob[s] * sum(value(g_conv[s,t]) for t in T) for s in scenarios))
println("Expected Curtailment: ", sum(prob[s] * sum(value(c_w[s,t] + c_pv3[s,t] + c_pv4[s,t]) for t in T) for s in scenarios))
println("Expected Load Shedding: ", sum(prob[s] * sum(value(LS3[s,t] + LS4[s,t]) for t in T) for s in scenarios))

println("Expected Charging: ", sum(prob[s] * sum(value(p_ch3[s,t] + p_ch4[s,t]) for t in T) for s in scenarios))
println("Expected Discharging: ", sum(prob[s] * sum(value(p_dis3[s,t] + p_dis4[s,t]) for t in T) for s in scenarios))
# Out:
# Expected Conventional Generation: 650.8879136078982
# Expected Curtailment: 0.3266666666666703
# Expected Load Shedding: 0.0
# Expected Charging: 58.80025352830093
# Expected Discharging: 41.67567325373605
